# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
def values_frequency(df, column, color="blue"):
    try:
        fig = plt.figure(figsize = (15,10))
        ax = fig.gca()
        df[column].value_counts().plot(ax=ax, kind='bar', color=color, edgecolor='black', title=f"Frequency values for column {column}")
    except Exception as ex:
        print(ex)

# %% [markdown]
# # Exploración de datos
# **Antes de ponernos a crear un modelo o nuevas variables, vamos a ver con que tipo de datos nos encontramos y ver cuan significativos pueden ser nuestros features.**

# %%
train = pd.read_csv("../data/train.csv")
test = pd.read_csv("../data/test.csv")

print(train.shape)
print(test.shape)
# Out:
# (12000, 13)
# (3000, 13)

# %%
print(train.info())
train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              12000 non-null  object
#  1   category                        12000 non-null  object
#  2   is_liquid                       12000 non-null  int64
#  3   nutritional_saturated_fat_100g  11662 non-null  float64
#  4   nutritional_carbohydrates_100g  11443 non-null  float64
#  5   nutritional_fat_100g            11866 non-null  float64
#  6   nutritional_sugars_100g         11680 non-null  float64
#  7   nutritional_proteins_100g       11717 non-null  float64
#  8   nutritional_fiber_100g          11590 non-null  float64
#  9   nutritional_energy_100g         11659 non-null  float64
#  10  nutritional_salt_100g           11492 non-null  float64
#  11  ingredients_ordered             12000 non-null  object
# ...

# %%
print(test.info())
test.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              3000 non-null   object
#  1   category                        3000 non-null   object
#  2   is_liquid                       3000 non-null   int64
#  3   nutritional_saturated_fat_100g  2906 non-null   float64
#  4   nutritional_carbohydrates_100g  2863 non-null   float64
#  5   nutritional_fat_100g            2961 non-null   float64
#  6   nutritional_sugars_100g         2921 non-null   float64
#  7   nutritional_proteins_100g       2933 non-null   float64
#  8   nutritional_fiber_100g          2900 non-null   float64
#  9   nutritional_energy_100g         2908 non-null   float64
#  10  nutritional_salt_100g           2873 non-null   float64
#  11  ingredients_ordered             3000 non-null   object
# ...

# %% [markdown]
# **Podemos plotear en gráficas la frecuencia de diferentes features, por ejemplo, para empezar, podemos mostrar la frecuencia en la columna de categoría, líquido/no_líquido, frecuencia de categorias líquidas/frecuencia de categorías líquidas...**

# %%
values_frequency(train, "category")
values_frequency(test, "category")

# %% [markdown]
# **También podemos visualizar para otras variables....**

# %%
values_frequency(train, "is_liquid", color=["lightgreen", "lightblue"])

# %% [markdown]
# **O ir más allá y filtrar por valores de la columna en si...**

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10), frameon=False)
train.loc[train["is_liquid"] == 0]['category'].value_counts().plot(ax=ax1, kind='bar', edgecolor='black', title="No liquids frequency")
train.loc[train["is_liquid"] == 1]['category'].value_counts().plot(ax=ax2, kind='bar', edgecolor='black', title="Liquids frequency")
# Out:
# <AxesSubplot:title={'center':'Liquids frequency'}>

# %% [markdown]
# **Haciendo este pequeña exploración nos permite analizar que tipo de datos nos llegan y nos ayudan a pensar en posibles features adicionales a partir de estos, como podría ser un feature adicional llamado is_not_liquid...**

# %% [markdown]
# **Por otra parte también podemos analizar el comportamiento más estadístico de los datos y ver si hay outliers. Nosotros asumiremos de primeras que los valores que nos dan son correctos, ya que no sabemos los alimentos al fin y al cabo, y se pueden dar situaciones con valores nutricionales altos respecto otros.**

# %%
train.select_dtypes("float64").hist(figsize=(16, 20), bins=50, xlabelsize=8, ylabelsize=8)
# Out:
# array([[<AxesSubplot:title={'center':'nutritional_saturated_fat_100g'}>,
#         <AxesSubplot:title={'center':'nutritional_carbohydrates_100g'}>,
#         <AxesSubplot:title={'center':'nutritional_fat_100g'}>],
#        [<AxesSubplot:title={'center':'nutritional_sugars_100g'}>,
#         <AxesSubplot:title={'center':'nutritional_proteins_100g'}>,
#         <AxesSubplot:title={'center':'nutritional_fiber_100g'}>],
#        [<AxesSubplot:title={'center':'nutritional_energy_100g'}>,
#         <AxesSubplot:title={'center':'nutritional_salt_100g'}>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# **Otro punto a tener en cuenta dentro de nuestro proceso de exploración es ver la correlación entre variables. Como podemos apreciar hay bastante correlación entre valores nutricionales como era de esperar!**

# %%
train.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_c88a0_row0_col0, #T_c88a0_row1_col1, #T_c88a0_row2_col2, #T_c88a0_row3_col3, #T_c88a0_row4_col4, #T_c88a0_row5_col5, #T_c88a0_row6_col6, #T_c88a0_row7_col7, #T_c88a0_row8_col8, #T_c88a0_row9_col9 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c88a0_row0_col1, #T_c88a0_row0_col2, #T_c88a0_row0_col3, #T_c88a0_row0_col5, #T_c88a0_row0_col6, #T_c88a0_row0_col7, #T_c88a0_row4_col8, #T_c88a0_row5_col4, #T_c88a0_row5_col9, #T_c88a0_row7_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c88a0_row0_col4, #T_c88a0_row0_col9, #T_c88a0_row2_col1, #T_c88a0_row3_col8 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_c88a0_row0_col8 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_c88a0_row1_col0, #T_c88a0_row8_col9 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_c88a0_row1_col2 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_c88a0_row1_col3 {
#   background-color: #1b7eb7;
# ...
